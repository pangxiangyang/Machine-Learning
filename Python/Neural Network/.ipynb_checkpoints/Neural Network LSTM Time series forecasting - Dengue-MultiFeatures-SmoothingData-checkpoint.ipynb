# %%
# Import raw data from Excel
import pandas as pd
filepath = 'C:/Users/PXY/Desktop/Orange_week.xlsx';
sheetname = 'main'
df = pd.read_excel ( filepath, sheet_name = sheetname );
print (df)
# Out:
#      Year    Week  Cases  Rainfalls  No.of Raindays  Max. temperature  \
# 0    2010   week1    NaN        NaN             NaN               NaN
# 1    2010   week2    NaN        NaN             NaN               NaN
# 2    2010   week3    NaN        NaN             NaN               NaN
# 3    2010   week4    NaN      286.0            22.0         32.883871
# 4    2010   week5    NaN        NaN             NaN               NaN
# 5    2010   week6    NaN        NaN             NaN               NaN
# 6    2010   week7    NaN        NaN             NaN               NaN
# 7    2010   week8   36.0      241.8            11.0         34.385714
# 8    2010   week9   65.0        NaN             NaN               NaN
# 9    2010  week10   46.0        NaN             NaN               NaN
# 10   2010  week11   31.0        NaN             NaN               NaN
# 11   2010  week12   27.0      191.8            14.0         34.338710
# 12   2010  week13   40.0        NaN             NaN               NaN
# 13   2010  week14   49.0        NaN             NaN               NaN
# 14   2010  week15   29.0        NaN             NaN               NaN
# 15   2010  week16   38.0      304.2            19.0         33.456667
# 16   2010  week17   40.0        NaN             NaN               NaN
# 17   2010  week18   38.0        NaN             NaN               NaN
# 18   2010  week19   33.0        NaN             NaN               NaN
# 19   2010  week20   37.0      366.4            18.0         33.493548
# 20   2010  week21   38.0        NaN             NaN               NaN
# 21   2010  week22   54.0        NaN             NaN               NaN
# 22   2010  week23   78.0        NaN             NaN               NaN
# 23   2010  week24   66.0      303.0            21.0         32.776667
# 24   2010  week25   78.0        NaN             NaN               NaN
# 25   2010  week26   63.0        NaN             NaN               NaN
# 26   2010  week27   56.0        NaN             NaN               NaN
# 27   2010  week28   38.0      173.8            15.0         32.629032
# 28   2010  week29   93.0        NaN             NaN               NaN
# 29   2010  week30   65.0        NaN             NaN               NaN
# ..    ...     ...    ...        ...             ...               ...
# 282  2015  week23    NaN        NaN             NaN               NaN
# 283  2015  week24    NaN      131.4            11.0         33.260000
# 284  2015  week25    NaN        NaN             NaN               NaN
# 285  2015  week26    NaN        NaN             NaN               NaN
# 286  2015  week27    NaN        NaN             NaN               NaN
# 287  2015  week28    NaN      115.6            14.0         33.538710
# 288  2015  week29    NaN        NaN             NaN               NaN
# 289  2015  week30    NaN        NaN             NaN               NaN
# 290  2015  week31    NaN        NaN             NaN               NaN
# 291  2015  week32    NaN       99.0            17.0         33.000000
# 292  2015  week33    NaN        NaN             NaN               NaN
# 293  2015  week34    NaN        NaN             NaN               NaN
# 294  2015  week35    NaN        NaN             NaN               NaN
# 295  2015  week36    NaN      135.2            14.0         32.670000
# 296  2015  week37    NaN        NaN             NaN               NaN
# 297  2015  week38    NaN        NaN             NaN               NaN
# 298  2015  week39    NaN        NaN             NaN               NaN
# 299  2015  week40    NaN      134.0            18.0         31.929032
# 300  2015  week41    NaN        NaN             NaN               NaN
# 301  2015  week42    NaN        NaN             NaN               NaN
# 302  2015  week43    NaN        NaN             NaN               NaN
# 303  2015  week44    NaN      487.2            25.0         31.946667
# 304  2015  week45    NaN        NaN             NaN               NaN
# 305  2015  week46    NaN        NaN             NaN               NaN
# 306  2015  week47    NaN        NaN             NaN               NaN
# 307  2015  week48    NaN      180.0            22.0         32.748387
# 308  2015  week49    NaN        NaN             NaN               NaN
# 309  2015  week50    NaN        NaN             NaN               NaN
# 310  2015  week51    NaN        NaN             NaN               NaN
# 311  2015  week52    NaN        NaN             NaN               NaN
#
#      Min. temperature  Mean temp  Fatality
# 0                 NaN        NaN       NaN
# 1                 NaN        NaN       NaN
# 2                 NaN        NaN       NaN
# 3           23.751613  26.945161       NaN
# 4                 NaN        NaN       NaN
# 5                 NaN        NaN       NaN
# 6                 NaN        NaN       NaN
# 7           24.535714  28.382143       NaN
# 8                 NaN        NaN       NaN
# 9                 NaN        NaN       NaN
# 10                NaN        NaN       NaN
# 11          24.470968  28.254839       NaN
# 12                NaN        NaN       NaN
# 13                NaN        NaN       1.0
# 14                NaN        NaN       NaN
# 15          24.576667  27.926667       NaN
# 16                NaN        NaN       1.0
# 17                NaN        NaN       NaN
# 18                NaN        NaN       NaN
# 19          24.800000  28.287097       NaN
# 20                NaN        NaN       NaN
# 21                NaN        NaN       NaN
# 22                NaN        NaN       1.0
# 23          23.873333  27.310000       1.0
# 24                NaN        NaN       NaN
# 25                NaN        NaN       NaN
# 26                NaN        NaN       NaN
# 27          23.851613  27.232258       NaN
# 28                NaN        NaN       1.0
# 29                NaN        NaN       NaN
# ..                ...        ...       ...
# 282               NaN        NaN       NaN
# 283         24.840000  28.266667       NaN
# 284               NaN        NaN       NaN
# 285               NaN        NaN       NaN
# 286               NaN        NaN       NaN
# 287         24.509677  28.032258       NaN
# 288               NaN        NaN       NaN
# 289               NaN        NaN       NaN
# 290               NaN        NaN       NaN
# 291         24.309677  27.587097       NaN
# 292               NaN        NaN       NaN
# 293               NaN        NaN       NaN
# 294               NaN        NaN       NaN
# 295         24.316667  27.623333       NaN
# 296               NaN        NaN       NaN
# 297               NaN        NaN       NaN
# 298               NaN        NaN       NaN
# 299         24.054839  26.864516       NaN
# 300               NaN        NaN       NaN
# 301               NaN        NaN       NaN
# 302               NaN        NaN       NaN
# 303         23.563333  26.326667       NaN
# 304               NaN        NaN       NaN
# 305               NaN        NaN       NaN
# 306               NaN        NaN       NaN
# 307         23.625806  26.948387       NaN
# 308               NaN        NaN       NaN
# 309               NaN        NaN       NaN
# 310               NaN        NaN       NaN
# 311               NaN        NaN       NaN
#
# [312 rows x 9 columns]

# %%
# Data preprocessing
# Set NaN to 0.0 for Cases & Fatality
df['Cases'].fillna( 0, inplace = True )
df['Fatality'].fillna(0, inplace = True )

# Set others to first found values
df['Rainfalls'].ffill( inplace = True );
df['Max. temperature'].ffill( inplace = True );
df['Min. temperature'].ffill( inplace = True );
df['Mean temp'].ffill( inplace = True );

# Ffill doesn't fill in the first three NaN, thus need to do another bfill
df['Rainfalls'].bfill( inplace = True );
df['Max. temperature'].bfill( inplace = True );
df['Min. temperature'].bfill( inplace = True );
df['Mean temp'].bfill( inplace = True );

# Add new column
import datetime 
date = []
for index,row in df.iterrows():
    row['Date'] = datetime.datetime.strptime( str( row['Year'])+ row['Week'] + "-1", "%Yweek%W-%w")
    date.append( row['Date'])

df['Date'] = date

# Verify if all the anomalies are gone and new column added succesfully
df.dtypes

# Create a new data frame
data = pd.DataFrame()
data['Date'] = df['Date']
data['Rainfalls'] = df['Rainfalls'];
data['Max. temperature'] = df['Max. temperature']
data['Min. temperature'] = df['Min. temperature']
data['Mean temp'] = df['Mean temp']
data['Cases'] = df['Cases']

# Since there is no case reported since 2015, drop 2015 data from time series prediction
data.drop(data.tail(52).index,inplace=True) #drop bottom 52 which is data from 2015 

# Show the data in chart
import matplotlib
import matplotlib.pyplot as plt
plt.figure()
dates = matplotlib.dates.date2num(df['Date'])
plt.plot_date(data['Date'], data['Cases'], linestyle = 'solid', marker = 'None')
plt.plot_date(data['Date'], data['Max. temperature'], linestyle = 'solid', marker = 'None', color = 'red')
plt.plot_date(data['Date'], data['Min. temperature'], linestyle = 'solid', marker = 'None', color = 'green')
plt.plot_date(data['Date'], data['Rainfalls'], linestyle = 'solid', marker = 'None', color = 'black')
plt.plot_date(data['Date'], data['Mean temp'], linestyle = 'solid', marker = 'None', color = 'orange' )

print( data.corr() )

# Filter anomalies by using mean+std dev or mean - std dev
std_value = data['Cases'].std()
mean_value = data['Cases'].mean()
max_boundary = mean_value + std_value
min_boundary = max( mean_value - std_value, 0 )
index = ( data['Cases'] > max_boundary ) | ( data['Cases'] < min_boundary )

import numpy as np
data.loc[index,'Cases'] = np.nan
data['Cases'].bfill( inplace = True );
data['Cases'].ffill( inplace = True );

plt.figure()
plt.plot_date(data['Date'], data['Cases'], linestyle = 'solid', marker = 'None' )
'''
#from scipy.signal import savgol_filter
#filtered_case = savgol_filter(data['Cases'], 11,2)
#plt.plot_date(dates,filtered_case,color ='red', linestyle = 'solid', marker= 'None')
#plt.show()'''
# Out:
#                   Rainfalls  Max. temperature  Min. temperature  Mean temp  \
# Rainfalls          1.000000         -0.339572         -0.276648  -0.415492
# Max. temperature  -0.339572          1.000000          0.702841   0.928815
# Min. temperature  -0.276648          0.702841          1.000000   0.864220
# Mean temp         -0.415492          0.928815          0.864220   1.000000
# Cases              0.171039         -0.261803         -0.159618  -0.217271
#
#                      Cases
# Rainfalls         0.171039
# Max. temperature -0.261803
# Min. temperature -0.159618
# Mean temp        -0.217271
# Cases             1.000000
# C:\Users\PXY\AppData\Local\conda\conda\envs\tf_gpu\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# "\n#from scipy.signal import savgol_filter\n#filtered_case = savgol_filter(data['Cases'], 11,2)\n#plt.plot_date(dates,filtered_case,color ='red', linestyle = 'solid', marker= 'None')\n#plt.show()"

# %%
# Normalizing data
# This step is really useful on improving model performance
import sklearn
from sklearn.preprocessing import MinMaxScaler
cols_to_norm = [ 'Max. temperature','Cases']
sc = MinMaxScaler();
scaled_data = data.copy()
scaled_data[cols_to_norm] = sc.fit_transform(data[cols_to_norm])
 
# Split into train and test sets",
train_size = int(len(data) * 0.8)
test_size = len(data) - train_size
train, test = scaled_data[:train_size], scaled_data.tail(test_size)

# Get the subset of the data for training
training_set = train.iloc[:, [2,5]].values
# Define the timestep
timestep = 5

# Create input for training
import numpy as np
X_train = []
y_train =[]
for i in range(timestep, len(training_set)):
    X_train.append(training_set[i-timestep:i,[0,1]]);
    y_train.append(training_set[i,1])

X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 2))

# %%
# Build and train the model
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout

regressor = tf.keras.Sequential()

regressor.add(LSTM(units = timestep, return_sequences = True, input_shape = (X_train.shape[1], 2)))
regressor.add(Dropout(0.2) )

regressor.add(LSTM(units = timestep, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = timestep, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = timestep))
regressor.add(Dropout(0.2))

regressor.add(Dense(units = 1))

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 203/203 [==============================] - 4s 21ms/sample - loss: 0.1240
# Epoch 2/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.1100
# Epoch 3/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0973
# Epoch 4/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0830
# Epoch 5/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0731
# Epoch 6/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0581
# Epoch 7/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0482
# Epoch 8/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0424
# Epoch 9/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0321
# Epoch 10/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0311
# Epoch 11/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0305
# Epoch 12/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0319
# Epoch 13/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0281
# Epoch 14/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0299
# Epoch 15/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0292
# Epoch 16/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0374
# Epoch 17/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0277
# Epoch 18/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0290
# Epoch 19/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0263
# Epoch 20/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0302
# Epoch 21/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0298
# Epoch 22/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0293
# Epoch 23/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0275
# Epoch 24/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0284
# Epoch 25/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0277
# Epoch 26/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0293
# Epoch 27/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0297
# Epoch 28/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0245
# Epoch 29/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0266
# Epoch 30/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0284
# Epoch 31/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0278
# Epoch 32/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0282
# Epoch 33/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0243
# Epoch 34/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0301
# Epoch 35/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0249
# Epoch 36/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0271
# Epoch 37/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0271
# Epoch 38/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0286
# Epoch 39/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0252
# Epoch 40/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0284
# Epoch 41/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0245
# Epoch 42/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0241
# Epoch 43/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0264
# Epoch 44/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0244
# Epoch 45/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0243
# Epoch 46/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0255
# Epoch 47/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0264
# Epoch 48/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0263
# Epoch 49/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0229
# Epoch 50/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0256
# Epoch 51/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0252
# Epoch 52/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0221
# Epoch 53/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0233
# Epoch 54/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0222
# Epoch 55/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0223
# Epoch 56/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0238
# Epoch 57/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0258
# Epoch 58/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0237
# Epoch 59/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0222
# Epoch 60/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0220
# Epoch 61/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0231
# Epoch 62/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0208
# Epoch 63/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0227
# Epoch 64/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0218
# Epoch 65/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0205
# Epoch 66/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0218
# Epoch 67/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0183
# Epoch 68/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0261
# Epoch 69/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0230
# Epoch 70/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0228
# Epoch 71/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0182
# Epoch 72/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0200
# Epoch 73/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0206
# Epoch 74/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0204
# Epoch 75/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0218
# Epoch 76/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0199
# Epoch 77/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0190
# Epoch 78/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0214
# Epoch 79/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0203
# Epoch 80/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0244
# Epoch 81/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0206
# Epoch 82/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0224
# Epoch 83/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0195
# Epoch 84/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0202
# Epoch 85/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0197
# Epoch 86/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0186
# Epoch 87/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0196
# Epoch 88/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0200
# Epoch 89/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0217
# Epoch 90/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0213
# Epoch 91/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0227
# Epoch 92/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0187
# Epoch 93/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0208
# Epoch 94/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0218
# Epoch 95/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0227
# Epoch 96/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0206
# Epoch 97/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0196
# Epoch 98/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0181
# Epoch 99/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0200
# Epoch 100/100
# 203/203 [==============================] - 0s 2ms/sample - loss: 0.0192

# %%
# Create test data for prediction
test_set = training_set[-timestep:]
test_set = np.concatenate(( (test.iloc[:, [2,5]].values),test_set ) )
X_test = []

for i in range(timestep, len(test) + timestep ):
    X_test.append(test_set[i-timestep:i, [0,1]])
   
X_test = np.array(X_test)

# Make prediction
predicted_cases = regressor.predict(X_test)

# Transform prediction result
result = np.zeros(shape=(len(predicted_cases),2))
result[:,1] = predicted_cases[:,0]
predict = sc.inverse_transform(result)[:,1]
print(predict)
# Out:
# [29.08144891 27.08675215 30.80033749 40.82061499 59.16215062 80.55849957
#  81.47288728 80.85672629 80.17455912 76.2238735  62.96863294 42.48083216
#  29.26176366 39.64216888 54.49936941 56.49848455 50.47967365 48.38841927
#  46.61066395 44.34277567 44.33802053 62.59982002 59.27688015 48.20089772
#  39.21761778 23.92437905 24.1644816  25.93291354 32.01365238 45.84281334
#  66.94941199 73.24299383 67.39887369 64.33838248 66.24550319 67.60788429
#  72.79948616 71.32960927 76.65325046 76.98504603 77.60524821 78.53259468
#  78.36151743 78.17148697 77.85340452 77.21512473 76.36990881 75.75431359
#  75.81483722 75.97890973 76.27162695 76.1089015 ]

# %%
# Get real data
real_cases = data['Cases'].tail(test_size).values

# Visualising the results
plt.plot(real_cases, color = 'red', label = 'Actual number of cases')
plt.plot(predict, color = 'blue', label = 'Predicted number of cases')
plt.title('Dengue case prediction')
plt.xlabel('Time')
plt.ylabel('Number of cases')
plt.legend()
plt.show()
